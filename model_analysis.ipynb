# %% [markdown]
# # Notebook for assignment Responsible AI predictive XAI exercise

# %%
import os
import matplotlib.pyplot as plt
import torchvision
import torch
import pandas as pd
import numpy as np

from utils.notebook import display_scrollable_dataframe,plot_sailency
from data_loaders import CUB_extnded_dataset
from models import get_inception_transform
from IPython.display import display

from sailency import get_saliency_maps,saliency_score_part

# %%
# Settings for the experiment your running
data_set = 'val' 

id = 533 # The id of the image you want to explain
id = 200

# Settings for loading the dataset, make sure its the same as the one used to train the model. 
# You can find the settings in the .hydra folders config.yaml 
data_config = {'CUB_dir':r'data/CUB_200_2011/CUB_200_2011/',
                'split_file':r'data/train_test_val.pkl',
                'use_majority_voting':True,
                'min_class_count':10,
                'return_visibility':True}

# %%
#Define data set, the human transformer data_set is used to get the original images instead of the normalized ones
transformer = get_inception_transform(mode='val',methode="center")
human_tansform = torchvision.transforms.Compose([torchvision.transforms.CenterCrop(299),torchvision.transforms.ToTensor()])

#Get dataset
data = CUB_extnded_dataset(mode=data_set,config_dict=data_config,transform=transformer)

#Get a dataset that return original images instead normalized ones
data_human = CUB_extnded_dataset(mode=data_set,config_dict=data_config,transform=human_tansform)
concept_names = data.consept_labels_names
class_names = data.class_labels_names
n_classes = data.n_classes
n_concepts = data.n_concepts

# %%
X, C, Y,coordinates = data.__getitem__(id)

print("Image shape: ",X.shape)
print("Concept shape: ",C.shape)
print("Label shape: ",Y.shape)
X = X.unsqueeze(0)

img ,_,_,_ = data_human.__getitem__(id)

print(Y.argmax())
# Out:
# Image shape:  torch.Size([3, 299, 299])
# Concept shape:  torch.Size([112])
# Label shape:  torch.Size([200])
# tensor(140)

# %%
# Separate the concepts and their visibility only relevant if visibility is used and no majority voting is used
if len(C.shape) == 2:
    Concepts = C[0]
    Concepts_visiblity = C[1]
else:
    Concepts = C.tolist()
    Concepts_visiblity = [None]*len(C)

# %%
# Show the image and the coordinates of the concepts
plt.imshow(img.permute(1, 2, 0))

for i in range(len(coordinates)):
    if len(coordinates[i]) > 0:
        #print(f'coordinates {coordinates[i]} atribute_locations_names {consept_labels_masked[i]}')
        for x,y in coordinates[i]:
            #plt.plot(x,y,'ro')
            name=concept_names[i].split("_")[1]
            if name == "forehead":
                ofset = -30

            elif name == "eye":
                ofset = 0
            else:
                ofset = 0
            
            plt.text(x+ofset,y,name,fontsize=9,color='red')
    plt.axis('off')
            
plt.size=(50,50)
plt.show()

# %% [markdown]
# # Expandability for Sequential and independent models.

# %%
#Load models make sure the model is trained with the same settings as the data loader
model_folder = r"models\Sequential_Basemodel3"

X_to_C_path = os.path.join(model_folder,"best_XtoC_model.pth")
C_to_Y_path = os.path.join(model_folder,"best_CtoY_model.pth")

ModelXtoC = torch.load(X_to_C_path,map_location=torch.device('cpu'))
ModelCtoY = torch.load(C_to_Y_path,map_location=torch.device('cpu'))
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19472\3045328997.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ModelXtoC = torch.load(X_to_C_path,map_location=torch.device('cpu'))
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19472\3045328997.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ModelCtoY = torch.load(C_to_Y_path,map_location=torch.device('cpu'))

# %%
#Make prediction
C_hat = ModelXtoC(X)
Y_hat = ModelCtoY(C_hat)

print(f"Predicted class: {Y_hat.argmax().item()} true class: {Y.argmax().item()} probability of true class: {Y_hat[0,Y.argmax()].item()}")
# Out:
# Predicted class: 145 true class: 140 probability of true class: 1.6627584045636468e-05

# %%
#Make Concept prediction and other stuff
weights = ModelCtoY.linear.weight[Y.argmax().item()] #Find the weigths of the bird you guessed on.
Concept_frame = pd.DataFrame({"Concept":concept_names,"Concept_true":Concepts,"Concept_visiblity":Concepts_visiblity,"Concept_pred":np.round(C_hat[0].detach().numpy(),2),"CtoY_weight":weights.detach().numpy()})
display_scrollable_dataframe(Concept_frame)
# Out:
#         <div style="max-height: 500px; overflow-y: auto; border: 1px solid #ccc; padding: 5px;">
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Concept</th>
#       <th>Concept_true</th>
#       <th>Concept_visiblity</th>
#       <th>Concept_pred</th>
#       <th>CtoY_weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>has_bill_shape::dagger</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>1.00</td>
#       <td>-0.008309</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>has_bill_shape::hooked_seabird</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.006446</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>has_bill_shape::all-purpose</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.047952</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>has_bill_shape::cone</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.026904</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>has_wing_color::brown</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.020240</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>has_wing_color::grey</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.06</td>
#       <td>-0.020043</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>has_wing_color::yellow</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.006488</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>has_wing_color::black</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.035329</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>has_wing_color::white</td>
#       <td>1.0</td>
#       <td>None</td>
#       <td>1.00</td>
#       <td>-0.012022</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>has_wing_color::buff</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.009571</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>has_upperparts_color::brown</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.020127</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>has_upperparts_color::grey</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.01</td>
#       <td>-0.024391</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>has_upperparts_color::yellow</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.008205</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>has_upperparts_color::black</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.033602</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>has_upperparts_color::white</td>
#       <td>1.0</td>
#       <td>None</td>
#       <td>1.00</td>
#       <td>-0.011088</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>has_upperparts_color::buff</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.009603</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>has_underparts_color::brown</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.005342</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>has_underparts_color::grey</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.011153</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>has_underparts_color::yellow</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.018383</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>has_underparts_color::black</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.011450</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>has_underparts_color::white</td>
#       <td>1.0</td>
#       <td>None</td>
#       <td>1.00</td>
#       <td>-0.039512</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>has_underparts_color::buff</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.010634</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>has_breast_pattern::solid</td>
#       <td>1.0</td>
#       <td>None</td>
#       <td>1.00</td>
#       <td>-0.071427</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>has_breast_pattern::striped</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.005087</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>has_breast_pattern::multi-colored</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.005813</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>has_back_color::brown</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.019244</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>has_back_color::grey</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.01</td>
#       <td>-0.024292</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>has_back_color::yellow</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.006084</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>has_back_color::black</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.01</td>
#       <td>-0.021100</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>has_back_color::white</td>
#       <td>1.0</td>
#       <td>None</td>
#       <td>1.00</td>
#       <td>-0.005279</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>has_back_color::buff</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.006719</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>has_tail_shape::notched_tail</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.028796</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>has_upper_tail_color::brown</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.015041</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>has_upper_tail_color::grey</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.016656</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>has_upper_tail_color::black</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.01</td>
#       <td>-0.024529</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>has_upper_tail_color::white</td>
#       <td>1.0</td>
#       <td>None</td>
#       <td>1.00</td>
#       <td>-0.005450</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>has_upper_tail_color::buff</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.007459</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>has_head_pattern::eyebrow</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.003782</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>has_head_pattern::plain</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.01</td>
#       <td>-0.021105</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>has_breast_color::brown</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.005406</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>has_breast_color::grey</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.009096</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>has_breast_color::yellow</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.018975</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>has_breast_color::black</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.012340</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>has_breast_color::white</td>
#       <td>1.0</td>
#       <td>None</td>
#       <td>1.00</td>
#       <td>-0.032873</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>has_breast_color::buff</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.008373</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>has_throat_color::grey</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.004309</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>has_throat_color::yellow</td>
#       <td>0.0</td>
#       <td>None</td>
#       <td>0.00</td>
#       <td>-0.014246</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>has_thr

# %%
#List of concepts to plot
concept_list = [51,50,111]

sailency_maps = get_saliency_maps(X,concept_list,ModelXtoC,method_type="vanilla")

plot_sailency(img,sailency_maps,concept_list,concept_names,coordinates)
